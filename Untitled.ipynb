# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
x = np.linspace(0, 10, 21)
y = np.cos(x) 
ax.plot(x, y)

k = 2
x = np.linspace(0, 10, 21)
y = k*np.cos(x) 
ax.plot(x, y)
